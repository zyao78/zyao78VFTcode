# %%
# !pip install geemap
# !pip install geetools
# Out:
# Requirement already satisfied: geemap in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (0.36.2)
# Requirement already satisfied: anywidget in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (0.9.18)
# Requirement already satisfied: bqplot in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (0.12.45)
# Requirement already satisfied: earthengine-api>=1.5.12 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (1.6.4)
# Requirement already satisfied: eerepr>=0.1.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (0.1.2)
# Requirement already satisfied: folium>=0.17.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (0.20.0)
# Requirement already satisfied: geocoder in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (0.20.0)
# Requirement already satisfied: ipytree in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (3.10.5)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (2.2.6)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (2.3.2)
# Requirement already satisfied: plotly in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (6.3.0)
# Requirement already satisfied: pyperclip in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (7.3.2)
# Requirement already satisfied: scooby in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geemap) (0.10.1)
# Requirement already satisfied: google-cloud-storage in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1.5.12->geemap) (3.3.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1.5.12->geemap) (2.179.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1.5.12->geemap) (2.40.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1.5.12->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1.5.12->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1.5.12->geemap) (2.32.5)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=1.5.12->geemap) (3.2.3)
# Requirement already satisfied: branca>=0.6.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from folium>=0.17.0->geemap) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from folium>=0.17.0->geemap) (3.1.6)
# Requirement already satisfied: xyzservices in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from folium>=0.17.0->geemap) (2025.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.5.12->geemap) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.5.12->geemap) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.5.12->geemap) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.5.12->geemap) (6.32.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.5.12->geemap) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.5.12->geemap) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.5.12->geemap) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.5.12->geemap) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from requests->earthengine-api>=1.5.12->geemap) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from requests->earthengine-api>=1.5.12->geemap) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from requests->earthengine-api>=1.5.12->geemap) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from requests->earthengine-api>=1.5.12->geemap) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.4.1->earthengine-api>=1.5.12->geemap) (0.6.1)
# Requirement already satisfied: ipywidgets in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.7)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.15)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4.6)
# Requirement already satisfied: decorator in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from anywidget->geemap) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from python-dateutil>=2.8.2->pandas->geemap) (1.17.0)
# Requirement already satisfied: click in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geocoder->geemap) (8.2.1)
# Requirement already satisfied: future in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-cloud-storage->earthengine-api>=1.5.12->geemap) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-cloud-storage->earthengine-api>=1.5.12->geemap) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-cloud-storage->earthengine-api>=1.5.12->geemap) (1.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geemap) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geemap) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geemap) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geemap) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geemap) (11.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from plotly->geemap) (2.2.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Collecting geetools
#   Downloading geetools-1.17.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting anyascii (from geetools)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting deprecated (from geetools)
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: earthengine-api>=1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geetools) (1.6.4)
# Collecting geopandas (from geetools)
#   Downloading geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geetools) (3.10.5)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geetools) (2.3.2)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geetools) (2.32.5)
# Collecting xee>=0.0.11 (from geetools)
#   Using cached xee-0.0.20-py3-none-any.whl.metadata (6.2 kB)
# Collecting yamlable (from geetools)
#   Using cached yamlable-1.1.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: google-cloud-storage in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1->geetools) (3.3.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1->geetools) (2.179.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1->geetools) (2.40.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1->geetools) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from earthengine-api>=1->geetools) (0.22.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=1->geetools) (3.2.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1->geetools) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1->geetools) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1->geetools) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1->geetools) (6.32.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1->geetools) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1->geetools) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1->geetools) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1->geetools) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from requests->geetools) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from requests->geetools) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from requests->geetools) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from requests->geetools) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.4.1->earthengine-api>=1->geetools) (0.6.1)
# Collecting xarray[parallel] (from xee>=0.0.11->geetools)
#   Downloading xarray-2025.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting pyproj (from xee>=0.0.11->geetools)
#   Downloading pyproj-3.7.1-cp310-cp310-win_amd64.whl.metadata (31 kB)
# Collecting affine (from xee>=0.0.11->geetools)
#   Using cached affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting wrapt<2,>=1.10 (from deprecated->geetools)
#   Downloading wrapt-1.17.3-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geopandas->geetools) (2.2.6)
# Collecting pyogrio>=0.7.2 (from geopandas->geetools)
#   Downloading pyogrio-0.11.1-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from geopandas->geetools) (25.0)
# Collecting shapely>=2.0.0 (from geopandas->geetools)
#   Downloading shapely-2.1.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from pandas->geetools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from pandas->geetools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from pandas->geetools) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from python-dateutil>=2.8.2->pandas->geetools) (1.17.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-cloud-storage->earthengine-api>=1->geetools) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-cloud-storage->earthengine-api>=1->geetools) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from google-cloud-storage->earthengine-api>=1->geetools) (1.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geetools) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geetools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geetools) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geetools) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from matplotlib->geetools) (11.3.0)
# Collecting dask[complete] (from xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading dask-2025.7.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: click>=8.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (8.2.1)
# Collecting cloudpickle>=3.0.0 (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting fsspec>=2021.09.0 (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting partd>=1.4.0 (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (6.0.2)
# Collecting toolz>=0.10.0 (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools)
#   Using cached toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting importlib_metadata>=4.13.0 (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting pyarrow>=14.0.1 (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading pyarrow-21.0.0-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting lz4>=4.3.2 (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading lz4-4.4.4-cp310-cp310-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from click>=8.1->dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (0.4.6)
# Collecting zipp>=3.20 (from importlib_metadata>=4.13.0->dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting locket (from partd>=1.4.0->dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools)
#   Using cached locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting distributed==2025.7.0 (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading distributed-2025.7.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting bokeh>=3.1.0 (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading bokeh-3.7.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (3.1.6)
# Collecting msgpack>=1.0.2 (from distributed==2025.7.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading msgpack-1.1.1-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from distributed==2025.7.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (7.0.0)
# Collecting sortedcontainers>=2.0.5 (from distributed==2025.7.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting tblib>=1.6.0 (from distributed==2025.7.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools)
#   Downloading tblib-3.1.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from distributed==2025.7.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (6.5.2)
# Collecting zict>=3.0.0 (from distributed==2025.7.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools)
#   Using cached zict-3.0.0-py2.py3-none-any.whl.metadata (899 bytes)
# Requirement already satisfied: narwhals>=1.13 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (2.2.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\vft-gee\lib\site-packages (from jinja2>=2.10.3->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (3.0.2)
# Downloading geetools-1.17.2-py3-none-any.whl (89 kB)
# Using cached xee-0.0.20-py3-none-any.whl (31 kB)
# Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading wrapt-1.17.3-cp310-cp310-win_amd64.whl (38 kB)
# Downloading geopandas-1.1.1-py3-none-any.whl (338 kB)
# Downloading pyogrio-0.11.1-cp310-cp310-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.2 MB 644.1 kB/s eta 0:00:30
#    - -------------------------------------- 0.5/19.2 MB 644.1 kB/s eta 0:00:30
#    - -------------------------------------- 0.8/19.2 MB 644.9 kB/s eta 0:00:29
#    - -------------------------------------- 0.8/19.2 MB 644.9 kB/s eta 0:00:29
#    -- ------------------------------------- 1.0/19.2 MB 591.7 kB/s eta 0:00:31
#    -- ------------------------------------- 1.0/19.2 MB 591.7 kB/s eta 0:00:31
#    -- ------------------------------------- 1.0/19.2 MB 591.7 kB/s eta 0:00:31
#    -- ------------------------------------- 1.3/19.2 MB 541.1 kB/s eta 0:00:34
#    -- ------------------------------------- 1.3/19.2 MB 541.1 kB/s eta 0:00:34
#    --- ------------------------------------ 1.6/19.2 MB 534.1 kB/s eta 0:00:34
#    --- ------------------------------------ 1.6/19.2 MB 534.1 kB/s eta 0:00:34
#    --- ------------------------------------ 1.8/19.2 MB 550.0 kB/s eta 0:00:32
#    --- ------------------------------------ 1.8/19.2 MB 550.0 kB/s eta 0:00:32
#    --- ------------------------------------ 1.8/19.2 MB 550.0 kB/s eta 0:00:32
#    ---- ----------------------------------- 2.1/19.2 MB 543.7 kB/s eta 0:00:32
#    ---- ----------------------------------- 2.1/19.2 MB 543.7 kB/s eta 0:00:32
#    ---- ----------------------------------- 2.4/19.2 MB 526.3 kB/s eta 0:00:33
#    ---- ----------------------------------- 2.4/19.2 MB 526.3 kB/s eta 0:00:33
#    ---- ----------------------------------- 2.4/19.2 MB 526.3 kB/s eta 0:00:33
#    ----- ---------------------------------- 2.6/19.2 MB 513.6 kB/s eta 0:00:33
#    ----- ---------------------------------- 2.6/19.2 MB 513.6 kB/s eta 0:00:33
#    ----- ---------------------------------- 2.9/19.2 MB 522.6 kB/s eta 0:00:32
#    ----- ---------------------------------- 2.9/19.2 MB 522.6 kB/s eta 0:00:32
#    ------ --------------------------------- 3.1/19.2 MB 522.8 kB/s eta 0:00:31
#    ------ --------------------------------- 3.1/19.2 MB 522.8 kB/s eta 0:00:31
#    ------- -------------------------------- 3.4/19.2 MB 529.8 kB/s eta 0:00:30
#    ------- -------------------------------- 3.4/19.2 MB 529.8 kB/s eta 0:00:30
#    ------- -------------------------------- 3.4/19.2 MB 529.8 kB/s eta 0:00:30
#    ------- -------------------------------- 3.7/19.2 MB 529.3 kB/s eta 0:00:30
#    -------- ------------------------------- 3.9/19.2 MB 535.0 kB/s eta 0:00:29
#    -------- ------------------------------- 3.9/19.2 MB 535.0 kB/s eta 0:00:29
#    -------- ------------------------------- 3.9/19.2 MB 535.0 kB/s eta 0:00:29
#    -------- ------------------------------- 4.2/19.2 MB 526.5 kB/s eta 0:00:29
#    -------- ------------------------------- 4.2/19.2 MB 526.5 kB/s eta 0:00:29
#    -------- ------------------------------- 4.2/19
#    ------- -------------------------------- 5.2/26.2 MB 852.4 kB/s eta 0:00:25
#    -------- ------------------------------- 5.5/26.2 MB 867.2 kB/s eta 0:00:24
#    -------- ------------------------------- 5.8/26.2 MB 865.7 kB/s eta 0:00:24
#    -------- ------------------------------- 5.8/26.2 MB 865.7 kB/s eta 0:00:24
#    -------- ------------------------------- 5.8/26.2 MB 865.7 kB/s eta 0:00:24
# ...
#    ---------------------------------------  26.0/26.2 MB 912.4 kB/s eta 0:00:01
#    ---------------------------------------  26.0/26.2 MB 912.4 kB/s eta 0:00:01
#    ---------------------------------------- 26.2/26.2 MB 909.3 kB/s  0:00:28
# Using cached toolz-1.0.0-py3-none-any.whl (56 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading distributed-2025.7.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 837.5 kB/s eta 0:00:01
#    -------------------- ------------------- 0.5/1.0 MB 837.5 kB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 838.9 kB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 892.2 kB/s  0:00:01
# Downloading bokeh-3.7.3-py3-none-any.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 1.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 0.8/7.0 MB 1.0 MB/s eta 0:00:07
#    ---- ----------------------------------- 0.8/7.0 MB 1.0 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/7.0 MB 968.5 kB/s eta 0:00:07
#    ------- -------------------------------- 1.3/7.0 MB 1.0 MB/s eta 0:00:06
#    -------- ------------------------------- 1.6/7.0 MB 987.0 kB/s eta 0:00:06
#    ---------- ----------------------------- 1.8/7.0 MB 959.1 kB/s eta 0:00:06
#    ----------- ---------------------------- 2.1/7.0 MB 995.1 kB/s eta 0:00:05
#    ------------- -------------------------- 2.4/7.0 MB 1.0 MB/s eta 0:00:05
#    ------------- -------------------------- 2.4/7.0 MB 1.0 MB/s eta 0:00:05
#    -------------- ------------------------- 2.6/7.0 MB 1.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 2.9/7.0 MB 1.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 3.1/7.0 MB 1.0 MB/s eta 0:00:04
#    ------------------- -------------------- 3.4/7.0 MB 1.0 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.0 MB 1.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 3.9/7.0 MB 1.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.2/7.0 MB 1.0 MB/s eta 0:00:03
#    ------------------------- -------------- 4.5/7.0 MB 1.1 MB/s eta 0:00:03
#    -------------------------- ------------- 4.7/7.0 MB 1.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 5.0/7.0 MB 1.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.2/7.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------- -------- 5.5/7.0 MB 1.1 MB/s eta 0:00:02
#    -------------------------------- ------- 5.8/7.0 MB 1.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 6.3/7.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 1.2 MB/s  0:00:05
# Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Downloading msgpack-1.1.1-cp310-cp310-win_amd64.whl (71 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading tblib-3.1.0-py3-none-any.whl (12 kB)
# Using cached zict-3.0.0-py2.py3-none-any.whl (43 kB)
# Using cached yamlable-1.1.1-py2.py3-none-any.whl (14 kB)
# Installing collected packages: sortedcontainers, zipp, zict, yamlable, wrapt, toolz, tblib, shapely, pyproj, pyogrio, pyarrow, msgpack, lz4, locket, fsspec, cloudpickle, anyascii, affine, partd, importlib_metadata, deprecated, xarray, geopandas, dask, bokeh, distributed, xee, geetools
#
#    - --------------------------------------  1/28 [zipp]
#    -- -------------------------------------  2/28 [zict]
#    -- -------------------------------------  2/28 [zict]
#    ----- ----------------------------------  4/28 [wrapt]
#    ------- --------------------------------  5/28 [toolz]
#    ------- --------------------------------  5/28 [toolz]
#    -------- -------------------------------  6/28 [tblib]
#    ---------- -----------------------------  7/28 [shapely]
#    ---------- -----------------------------  7/28 [shapely]
#    ---------- -----------------------------  7/28 [shapely]
#    ---------- -----------------------------  7/28 [shapely]
#    ---------- -----------------------------  7/28 [shapely]
#    ---------- -----------------------------  7/28 [shapely]
#    ---------- -----------------------------  7/28 [shapely]
#    ---------- -----------------------------  7/28 [shapely]
#    ---------- -----------------------------  7/28 [shapely]
#    ----------- ----------------------------  8/28 [pyproj]
#    ----------- ----------------------------  8/28 [pyproj]
#    ----------- ----------------------------  8/28 [pyproj]
#    ----------- ----------------------------  8/28 [pyproj]
#    ------------ ---------------------------  9/28 [pyogrio]
#    ------------ ---------------------------  9/28 [pyogrio]
#    ------------ ---------------------------  9/28 [pyogrio]
#    ------------ ---------------------------  9/28 [pyogrio]
#    ------------ ---------------------------  9/28 [pyogrio]
#    ------------ ---------------------------  9/28 [pyogrio]
#    ------------ ---------------------------  9/28 [pyogrio]
#    ------------ ---------------------------  9/28 [pyogrio]
#    ------------ ---------------------------  9/28 [pyogrio]
#    ------------ ---------------------------  9/28 [pyogrio]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    -------------- ------------------------- 10/28 [pyarrow]
#    ------------------ --------------------- 13/28 [locket]
#    -------------------- ------------------- 14/28 [fsspec]
#    -------------------- ------------------- 14/28 [fsspec]
#    -------------------- ------------------- 14/28 [fsspec]
#    -------------------- ------------------- 14/28 [fsspec]
#    -------------------- ------------------- 14/28 [fsspec]
#    ---------------------- ----------------- 16/28 [anyascii]
#    ---------------------- ----------------- 16/28 [anyascii]
#    ---------------------- ----------------- 16/28 [anyascii]
#    ---------------------- ----------------- 16/28 [anyascii]
#    ---------------------- ----------------- 16/28 [anyascii]
#    ---------------------- ----------------- 16/28 [anyascii]
#    ---------------------- ----------------- 16/28 [anyascii]
#    ---------------------- ----------------- 16/28 [anyascii]
#    ------------------------- -------------- 18/28 [partd]
#    --------------------------- ------------ 19/28 [importlib_metadata]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------ --------- 21/28 [xarray]
#    ------------------------------- -------- 22/28 [geopandas]
#    ------------------------------- -------- 22/28 [geopandas]
#    ------------------------------- -------- 22/28 [geopandas]
#    ------------------------------- -------- 22/28 [geopandas]
#    ------------------------------- -------- 22/28 [geopandas]
#    ------------------------------- -------- 22/28 [geopandas]
#    ------------------------------- -------- 22/28 [geopandas]
#    ------------------------------- -------- 22/28 [geopandas]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    -------------------------------- ------- 23/28 [dask]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ---------------------------------- ----- 24/28 [bokeh]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    ----------------------------------- ---- 25/28 [distributed]
#    -------------------------------------- - 27/28 [geetools]
#    -------------------------------------- - 27/28 [geetools]
#    ---------------------------------------- 28/28 [geetools]
#
# Successfully installed affine-2.4.0 anyascii-0.3.3 bokeh-3.7.3 cloudpickle-3.1.1 dask-2025.7.0 deprecated-1.2.18 distributed-2025.7.0 fsspec-2025.7.0 geetools-1.17.2 geopandas-1.1.1 importlib_metadata-8.7.0 locket-1.0.0 lz4-4.4.4 msgpack-1.1.1 partd-1.4.2 pyarrow-21.0.0 pyogrio-0.11.1 pyproj-3.7.1 shapely-2.1.1 sortedcontainers-2.4.0 tblib-3.1.0 toolz-1.0.0 wrapt-1.17.3 xarray-2025.6.1 xee-0.0.20 yamlable-1.1.1 zict-3.0.0 zipp-3.23.0

# %%
import sys, subprocess
print(sys.executable) 
subprocess.check_call([sys.executable, "-m", "pip", "install", "-U",
    "python-dotenv", "pydrive2", "oauth2client"
])
# Out:
# C:\Users\Dell\anaconda3\envs\vft-gee\python.exe
# 0

# %%
#Import Libraries
import ee 
import geemap
import geetools

# %%
#authenticate and initialize ee

ee.Authenticate()
#ee.Authenticate(auth_mode='notebook', cloud_api=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %%
ee.Initialize()

# %%
# Define individual features
B1 = ee.Feature(ee.Geometry.Point([-79.21025, 35.14636]), {'name': 'B1', 'type': 'site'})
B2 = ee.Feature(ee.Geometry.Point([-79.19908, 35.14625]), {'name': 'B2', 'type': 'site'})
CM = ee.Feature(ee.Geometry.Point([-76.97426, 34.76602]), {'name': 'CM', 'type': 'site'})
CH = ee.Feature(ee.Geometry.Point([-76.87395833, 34.767175]), {'name': 'CH', 'type': 'site'})
ME = ee.Feature(ee.Geometry.Point([-77.47046, 34.64371]), {'name': 'ME', 'type': 'site'})
IA = ee.Feature(ee.Geometry.Point([-77.30881, 34.59154]), {'name': 'IA', 'type': 'site'})
GSP_BI = ee.Feature(ee.Geometry.Point([-78.30196, 34.08546]), {'name': 'GSP_BI', 'type': 'site'})
GSP_LI = ee.Feature(ee.Geometry.Point([-78.29995, 34.081985]), {'name': 'GSP_LI', 'type': 'site'})

# %%
# Create a FeatureCollection
VFT_sites = ee.FeatureCollection([B1, B2, CM,CH,ME,IA,GSP_BI,GSP_LI])
#bands = ['SR_B1','SR_B3','SR_B4','SR_B5', 'SR_B7','QA_PIXEL'] 
bands= ['SR_B1','SR_B2','SR_B3','SR_B4','SR_B5', 'SR_B6','SR_B7','QA_PIXEL']
#bands = image.bandNames()         # add desirable bands, and QA_pixel (cloud info). Depends on the index to calculate. Modify this when switching satellites
roi_GSP = ee.Geometry.Rectangle([-78.33, 34.05, -78.24, 34.13])  # [minLon, minLat, maxLon, maxLat]
roi_Lej = ee.Geometry.Rectangle([-77.55, 34.52, -77.23, 34.73])  # [minLon, minLat, maxLon, maxLat]
roi_Cro = ee.Geometry.Rectangle([-77.02, 34.72, -76.83, 34.82])  # [minLon, minLat, maxLon, maxLat]
roi_BR = ee.Geometry.Rectangle([-79.225, 35.13, -79.19, 35.16])  # [minLon, minLat, maxLon, maxLat]

# %%
collection = (ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')  # LANDSAT/LT05/C02/T1_L2    LANDSAT/LC08/C02/T1_L2
    .filterDate('2024-12-01', '2025-8-25')   
    .filterBounds(roi_Lej)  # Change ROI as needed 
    .select(bands)  # Select required bands, make su;re QA_pixel is in there
)

# Check number of images remaining
print("Number of images after filtering:", collection.size().getInfo())
# Out:
# Number of images after filtering: 27

# %%
import time

# %%
def export_image(image):
    img_id = image.get('system:index').getInfo()
    
    # Convert to float and clip to roi
    image = image.float().clip(roi_Lej)  # modify this when switching areas

    task = ee.batch.Export.image.toDrive(
        image=image,
        description=f'Landsat_{img_id}',
        folder='Landsat8_Lej',  # Google Drive Folder   # modify this when switching areas
        fileNamePrefix=f'Landsat_{img_id}',
        scale=30,  # 30m resolution
        region=roi_Lej.getInfo()['coordinates'],     # modify this when switching areas
        maxPixels=1e13
    )
    task.start()
    return task, img_id  # Return task and image ID for monitoring

# Convert collection to list and check if it contains images
num_images = collection.size().getInfo()
if num_images == 0:
    raise ValueError("🚨 No images found! ")

print(f"✅ Found {num_images} images. Starting export...")

# Export each image
image_list = collection.toList(num_images)
tasks = []

for i in range(num_images):
    img = ee.Image(image_list.get(i))
    task, img_id = export_image(img)
    tasks.append((task, img_id))  # Store task for monitoring

print("\n🚀 Batch export started. Monitoring progress...\n")

# Function to check task status
def check_task_status(tasks):
    while any(task.status()['state'] in ['READY', 'RUNNING'] for task, _ in tasks):
        print("\n🔄 Current Export Status:")
        for task, img_id in tasks:
            status = task.status()
            print(f"  - {img_id}: {status['state']}")
        time.sleep(100)  # Wait 5 minutes before checking again

    print("\n✅ All tasks completed!")

# Monitor progress
check_task_status(tasks)
# Out:
# ✅ Found 27 images. Starting export...
#
# 🚀 Batch export started. Monitoring progress...
#
#
# 🔄 Current Export Status:
#   - LC08_014036_20241208: RUNNING
#   - LC08_014036_20250109: RUNNING
#   - LC08_014036_20250125: RUNNING
#   - LC08_014036_20250226: READY
#   - LC08_014036_20250330: READY
#   - LC08_014036_20250415: READY
#   - LC08_014036_20250501: READY
#   - LC08_014036_20250517: READY
#   - LC08_014036_20250602: READY
#   - LC08_014036_20250618: READY
#   - LC08_014036_20250704: READY
#   - LC08_014036_20250720: READY
#   - LC08_014036_20250805: READY
#   - LC08_015036_20241215: READY
#   - LC08_015036_20241231: READY
#   - LC08_015036_20250116: READY
#   - LC08_015036_20250201: READY
#   - LC08_015036_20250217: READY
#   - LC08_015036_20250321: READY
#   - LC08_015036_20250406: READY
#   - LC08_015036_20250422: READY
#   - LC08_015036_20250508: READY
#   - LC08_015036_20250524: READY
#   - LC08_015036_20250609: READY
#   - LC08_015036_20250625: READY
#   - LC08_015036_20250711: READY
#   - LC08_015036_20250727: READY
#
# 🔄 Current Export Status:
#   - LC08_014036_20241208: COMPLETED
#   - LC08_014036_20250109: COMPLETED
#   - LC08_014036_20250125: COMPLETED
#   - LC08_014036_20250226: COMPLETED
#   - LC08_014036_20250330: RUNNING
#   - LC08_014036_20250415: RUNNING
#   - LC08_014036_20250501: RUNNING
#   - LC08_014036_20250517: READY
#   - LC08_014036_20250602: READY
#   - LC08_014036_20250618: READY
#   - LC08_014036_20250704: READY
#   - LC08_014036_20250720: READY
#   - LC08_014036_20250805: READY
#   - LC08_015036_20241215: READY
#   - LC08_015036_20241231: READY
#   - LC08_015036_20250116: READY
#   - LC08_015036_20250201: READY
#   - LC08_015036_20250217: READY
#   - LC08_015036_20250321: READY
#   - LC08_015036_20250406: READY
#   - LC08_015036_20250422: READY
#   - LC08_015036_20250508: READY
#   - LC08_015036_20250524: READY
#   - LC08_015036_20250609: READY
#   - LC08_015036_20250625: READY
#   - LC08_015036_20250711: READY
#   - LC08_015036_20250727: READY
#
#   - LC08_015036_20250711: READY
#   - LC08_015036_20250727: READY
#
# ✅ All tasks completed!

# %%
import os, glob
print(os.getcwd())
# Out:
# F:\VFT\VFT_github\zyao78VFTcode

# %%
from googleapiclient.errors import HttpError

def merge_folders_by_name(folder_name: str, delete_duplicates=True, dry_run=False):
    # Drive v2 query: use title (not name)
    q = ("title = '{0}' and "
         "mimeType = 'application/vnd.google-apps.folder' and trashed = false").format(folder_name)

    folders = drive.ListFile({
        'q': q,
        'supportsAllDrives': True,
        'includeItemsFromAllDrives': True,
        'maxResults': 1000
    }).GetList()

    if len(folders) < 2:
        print(f"Found {len(folders)} folder(s) named '{folder_name}'. Nothing to merge.")
        return

    target = folders[0]
    target_id = target['id']
    print(f"Found {len(folders)} folder(s) named '{folder_name}'.")
    print(f"Target: {target['title']} ({target_id})")

    svc = drive.auth.service

    for dup in folders[1:]:
        dup_id = dup['id']
        print(f"Merging: {dup['title']} ({dup_id}) -> {folder_name}")

        children = drive.ListFile({
            'q': f"'{dup_id}' in parents and trashed = false",
            'supportsAllDrives': True,
            'includeItemsFromAllDrives': True,
            'maxResults': 1000
        }).GetList()

        for it in children:
            file_id = it['id']
            title   = it['title']

            if dry_run:
                print(f"  would move: {title} -> target ({target_id})")
                continue

            # remove other parents and add target
            old_parents = ",".join(p['id'] for p in it.get('parents', []) if p['id'] != target_id)
            svc.files().update(
                fileId=file_id,
                addParents=target_id,
                removeParents=old_parents,
                supportsAllDrives=True
            ).execute()
            print(f"  moved: {title}")

        if not dry_run and delete_duplicates:
            svc.files().delete(fileId=dup_id, supportsAllDrives=True).execute()
            print(f"  deleted folder: {dup['title']} ({dup_id})")

    print("Done.")

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

# Sign in with your Google account (opens a browser tab)
gauth = GoogleAuth()
gauth.LocalWebserverAuth()
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=548363215141-24o3chdgv280l66mi2s58ebv2bga5kkm.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=online&response_type=code
#
# Authentication successful.

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

# assume you've already authenticated: gauth = GoogleAuth(); gauth.LocalWebserverAuth()
# drive = GoogleDrive(gauth)

def _list(q: str):
    return drive.ListFile({
        'q': q,
        'supportsAllDrives': True,
        'includeItemsFromAllDrives': True
    }).GetList()

# %%
# Dry run
merge_folders_by_name("Landsat8_BR", dry_run=True)
# Out:
# Found 29 folder(s) named 'Landsat8_BR'.
# Target: Landsat8_BR (19fgXJUseqMq3qA9oln_BVT93vf8TSe8N)
# Merging: Landsat8_BR (1hAihZsoRwcrRMEdpGKeHvLoxpMuzkuNm)
#   would move: Landsat_LC08_016035_20241206.tif -> Landsat8_BR
# Merging: Landsat8_BR (1GmKJpeHLkuaWygO1QgtbufpshC23OcJD)
#   would move: Landsat_LC08_016035_20250107.tif -> Landsat8_BR
# Merging: Landsat8_BR (1oKENsNLUpuQ5RfrRCsgmyig78b2e5ua9)
#   would move: Landsat_LC08_016035_20250123.tif -> Landsat8_BR
# Merging: Landsat8_BR (1LqBFTJizRscJrVX956PjksCUcAWFcWfS)
#   would move: Landsat_LC08_016035_20250224.tif -> Landsat8_BR
# Merging: Landsat8_BR (1h8KcGT5QLtkV4hpitniycEIvdzmQ_kQL)
#   would move: Landsat_LC08_016035_20250312.tif -> Landsat8_BR
# Merging: Landsat8_BR (1gjomPxEne401T_ybHieY6Xl-eOyvW5IA)
#   would move: Landsat_LC08_016035_20250328.tif -> Landsat8_BR
# Merging: Landsat8_BR (1G7ZaNu0yD4YRe4P37kScR8cIAsj00REn)
#   would move: Landsat_LC08_016035_20250413.tif -> Landsat8_BR
# Merging: Landsat8_BR (1k3BqCi_igKxjOoY7OyYC7a0h79hxQJB8)
#   would move: Landsat_LC08_016035_20250429.tif -> Landsat8_BR
# Merging: Landsat8_BR (1OjywdLgE6BEP-gvaNJSAX5coKXFtPpud)
#   would move: Landsat_LC08_016035_20250515.tif -> Landsat8_BR
# Merging: Landsat8_BR (14Pu7V8eGg0Lccx2oygohcimIP4tGag67)
#   would move: Landsat_LC08_016035_20250531.tif -> Landsat8_BR
# Merging: Landsat8_BR (1pdUIN5AjvdYjQFguESjxTc-EGyGPQYfa)
#   would move: Landsat_LC08_016035_20250616.tif -> Landsat8_BR
# Merging: Landsat8_BR (1Zei3kiOOf5CSV24J0RWuDTDoDa9UX5Ly)
#   would move: Landsat_LC08_016035_20250718.tif -> Landsat8_BR
# Merging: Landsat8_BR (1nxRQLNuki04BMyC16IJPx7aVgy5d1j4V)
#   would move: Landsat_LC08_016035_20250803.tif -> Landsat8_BR
# Merging: Landsat8_BR (1QX4ogu7FF-nEkqlJd1kaIXwmNtiRkOll)
#   would move: Landsat_LC08_016036_20241206.tif -> Landsat8_BR
# Merging: Landsat8_BR (1lsWUgez-rDPJWwn3bDThltgfB5cfA59Y)
#   would move: Landsat_LC08_016036_20241222.tif -> Landsat8_BR
# Merging: Landsat8_BR (1i8pFwRFcg8kx8TCAhKctiUFgILmk69Nn)
#   would move: Landsat_LC08_016036_20250107.tif -> Landsat8_BR
# Merging: Landsat8_BR (1xg1aXn4h-_dBLQgyX1Nztua-nKLBN5C6)
#   would move: Landsat_LC08_016036_20250123.tif -> Landsat8_BR
# Merging: Landsat8_BR (19UQukUc9Dwx3ug7jyiPwp9aaY3hiAdyW)
#   would move: Landsat_LC08_016036_20250224.tif -> Landsat8_BR
# Merging: Landsat8_BR (13RG512yRtVw6EKxuw430UZVCmozmD_ec)
#   would move: Landsat_LC08_016036_20250312.tif -> Landsat8_BR
# Merging: Landsat8_BR (1yMTs9BFQS6PEmG9_XssfbrdjbBphUApK)
#   would move: Landsat_LC08_016036_20250328.tif -> Landsat8_BR
# Merging: Landsat8_BR (1a9fgRX9L-v58JzgD2zOybszINlNxFxJD)
#   would move: Landsat_LC08_016036_20250413.tif -> Landsat8_BR
# Merging: Landsat8_BR (1BFeQGVS4NQHIiCTRupUeQwe2aRi5qMoM)
#   would move: Landsat_LC08_016036_20250429.tif -> Landsat8_BR
# Merging: Landsat8_BR (1JaK0cps--yP7qjSU00QvB637p8vuBekr)
#   would move: Landsat_LC08_016036_20250515.tif -> Landsat8_BR
# Merging: Landsat8_BR (1kre72ckntpymWywMLBJyYR0LreZ0w3MT)
#   would move: Landsat_LC08_016036_20250531.tif -> Landsat8_BR
# Merging: Landsat8_BR (1RCdwAJlSp701Uf66hPY18-JelWKGkL7s)
#   would move: Landsat_LC08_016036_20250616.tif -> Landsat8_BR
# Merging: Landsat8_BR (12ohJUdWIOI16tAEE8FfX5IrzAhgMV-WP)
#   would move: Landsat_LC08_016036_20250702.tif -> Landsat8_BR
# Merging: Landsat8_BR (1SphKYFmi6_-naKum-G-fwAp6HJtjsNVZ)
#   would move: Landsat_LC08_016036_20250718.tif -> Landsat8_BR
# Merging: Landsat8_BR (1zC2rKbf6wfBJDDcOJvcT9kilx31f45d_)
#   would move: Landsat_LC08_016036_20250803.tif -> Landsat8_BR
# Done.

# %%
merge_folders_by_name("Landsat8_Lej", dry_run=False)
# Out:
# Found 27 folder(s) named 'Landsat8_Lej'.
# Target: Landsat8_Lej (1EhSyJHAriyDjMPnMC-pjFS0xMPD4BBXa)
# Merging: Landsat8_Lej (1ZueIojFnDHiQD73OV6VrhBtA5MjOwfZ3) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250711.tif
#   deleted folder: Landsat8_Lej (1ZueIojFnDHiQD73OV6VrhBtA5MjOwfZ3)
# Merging: Landsat8_Lej (1CmLwVvdUfLrrX0iXEwuEbwDn8rH-QLmX) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250625.tif
#   deleted folder: Landsat8_Lej (1CmLwVvdUfLrrX0iXEwuEbwDn8rH-QLmX)
# Merging: Landsat8_Lej (1ycjp3g_MRPEyMs2Ps2d2mxKtxDmJLqJF) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250609.tif
#   deleted folder: Landsat8_Lej (1ycjp3g_MRPEyMs2Ps2d2mxKtxDmJLqJF)
# Merging: Landsat8_Lej (130lm3Z_V457QrM28flbxr11ZH0wMzi8n) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250524.tif
#   deleted folder: Landsat8_Lej (130lm3Z_V457QrM28flbxr11ZH0wMzi8n)
# Merging: Landsat8_Lej (1-IZ7BAAf9n_hEE24irIUiTNujwTGn36I) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250508.tif
#   deleted folder: Landsat8_Lej (1-IZ7BAAf9n_hEE24irIUiTNujwTGn36I)
# Merging: Landsat8_Lej (1SWsKFbLk0NifIJHJXb_HocvDDLUOdT-d) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250422.tif
#   deleted folder: Landsat8_Lej (1SWsKFbLk0NifIJHJXb_HocvDDLUOdT-d)
# Merging: Landsat8_Lej (1S7Wz_vGopdvIbtaLidumREjIz1G2SOqA) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250406.tif
#   deleted folder: Landsat8_Lej (1S7Wz_vGopdvIbtaLidumREjIz1G2SOqA)
# Merging: Landsat8_Lej (1hgDd-gZfjwIOahA0WjezdfSNaMIvUu7I) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250321.tif
#   deleted folder: Landsat8_Lej (1hgDd-gZfjwIOahA0WjezdfSNaMIvUu7I)
# Merging: Landsat8_Lej (1VgMiztXLKg1RBwFlzLfFMscNNrCk2OmX) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250217.tif
#   deleted folder: Landsat8_Lej (1VgMiztXLKg1RBwFlzLfFMscNNrCk2OmX)
# Merging: Landsat8_Lej (1120ulsyRF5UL_7WU3JA3mILHL2ze5J6E) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250201.tif
#   deleted folder: Landsat8_Lej (1120ulsyRF5UL_7WU3JA3mILHL2ze5J6E)
# Merging: Landsat8_Lej (1DpQxImFtfXyoqquAKAqdBPzG0SgR5-DY) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20250116.tif
#   deleted folder: Landsat8_Lej (1DpQxImFtfXyoqquAKAqdBPzG0SgR5-DY)
# Merging: Landsat8_Lej (1YW2YP9B3pncvICro9UR3HlhgcOOcJZ5d) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20241231.tif
#   deleted folder: Landsat8_Lej (1YW2YP9B3pncvICro9UR3HlhgcOOcJZ5d)
# Merging: Landsat8_Lej (13vr3e4F7G7rdEq-4IpP8b_ij_mPHefo3) -> Landsat8_Lej
#   moved: Landsat_LC08_015036_20241215.tif
#   deleted folder: Landsat8_Lej (13vr3e4F7G7rdEq-4IpP8b_ij_mPHefo3)
# Merging: Landsat8_Lej (1xUjvmnceBh6olEwpwaXk9dWNFQqh6fYX) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250805.tif
#   deleted folder: Landsat8_Lej (1xUjvmnceBh6olEwpwaXk9dWNFQqh6fYX)
# Merging: Landsat8_Lej (1SAEmZ5huS02nCzEKF7wUXVfpGkdNysLX) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250720.tif
#   deleted folder: Landsat8_Lej (1SAEmZ5huS02nCzEKF7wUXVfpGkdNysLX)
# Merging: Landsat8_Lej (1fBuJsPo_O5YCUzX0T02FUQaQwI_Ua-tj) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250704.tif
#   deleted folder: Landsat8_Lej (1fBuJsPo_O5YCUzX0T02FUQaQwI_Ua-tj)
# Merging: Landsat8_Lej (116xg3cJt1b4oCaLa8z8rdX-ov0y6AGa5) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250618.tif
#   deleted folder: Landsat8_Lej (116xg3cJt1b4oCaLa8z8rdX-ov0y6AGa5)
# Merging: Landsat8_Lej (1yREh_P6e9uEmeMftlMBwEfkEC0irNuIV) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250602.tif
#   deleted folder: Landsat8_Lej (1yREh_P6e9uEmeMftlMBwEfkEC0irNuIV)
# Merging: Landsat8_Lej (1j9Kvh1gS6ENZ2Y7EMY8aCvRSpLI0KkrM) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250517.tif
#   deleted folder: Landsat8_Lej (1j9Kvh1gS6ENZ2Y7EMY8aCvRSpLI0KkrM)
# Merging: Landsat8_Lej (1hwhf115VIDyHN2rMvzuCmYylVQdcKzsz) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250501.tif
#   deleted folder: Landsat8_Lej (1hwhf115VIDyHN2rMvzuCmYylVQdcKzsz)
# Merging: Landsat8_Lej (1flCYuCcRepgzEEYUnkMOstgUGYUzf9ek) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250415.tif
#   deleted folder: Landsat8_Lej (1flCYuCcRepgzEEYUnkMOstgUGYUzf9ek)
# Merging: Landsat8_Lej (1HDELfR0puSMQ0wiOmg59-30433MaWzCF) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250330.tif
#   deleted folder: Landsat8_Lej (1HDELfR0puSMQ0wiOmg59-30433MaWzCF)
# Merging: Landsat8_Lej (1cb8ybUNvxAeD02Gq8B0wJgAn05kJoZlC) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250226.tif
#   deleted folder: Landsat8_Lej (1cb8ybUNvxAeD02Gq8B0wJgAn05kJoZlC)
# Merging: Landsat8_Lej (1w4cF7B8Smvu_m0ZTfN2f8F86Ac556zJQ) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20241208.tif
#   deleted folder: Landsat8_Lej (1w4cF7B8Smvu_m0ZTfN2f8F86Ac556zJQ)
# Merging: Landsat8_Lej (1IMGT3gPea-Iv1q8WmjomuI7dbwifWhzv) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250125.tif
#   deleted folder: Landsat8_Lej (1IMGT3gPea-Iv1q8WmjomuI7dbwifWhzv)
# Merging: Landsat8_Lej (1f1rtXOU0KGlMxo-8ix2ClezThUxWxCZz) -> Landsat8_Lej
#   moved: Landsat_LC08_014036_20250109.tif
#   deleted folder: Landsat8_Lej (1f1rtXOU0KGlMxo-8ix2ClezThUxWxCZz)
# Done.
