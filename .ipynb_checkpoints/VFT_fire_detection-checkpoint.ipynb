# %%
# !pip install geemap
# !pip install geetools
# !pip install earthengine-api geemap geetools
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geemap in c:\users\dell\appdata\roaming\python\python311\site-packages (0.37.2)
# Requirement already satisfied: anywidget in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (0.9.13)
# Requirement already satisfied: bqplot in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.13.1)
# Requirement already satisfied: earthengine-api>=1.6.12 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (1.7.28)
# Requirement already satisfied: eerepr>=0.1.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.1.2)
# Requirement already satisfied: folium>=0.17.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.20.0)
# Requirement already satisfied: geocoder in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (2.0.4)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.20.0)
# Requirement already satisfied: matplotlib in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (3.9.4)
# Requirement already satisfied: numpy in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (2.2.3)
# Requirement already satisfied: plotly in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (6.7.0)
# Requirement already satisfied: pyperclip in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (1.11.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (7.4.1)
# Requirement already satisfied: requests in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (2.32.3)
# Requirement already satisfied: scooby in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.11.2)
# Requirement already satisfied: google-cloud-storage in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geemap) (3.10.1)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geemap) (2.196.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geemap) (2.53.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geemap) (0.4.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geemap) (0.31.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from folium>=0.17.0->geemap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from folium>=0.17.0->geemap) (3.1.5)
# Requirement already satisfied: xyzservices in c:\users\dell\appdata\roaming\python\python311\site-packages (from folium>=0.17.0->geemap) (2026.3.0)
# Requirement already satisfied: ipywidgets in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.5)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipyleaflet>=0.19.2->geemap) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.3)
# Requirement already satisfied: psygnal>=0.8.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from anywidget->geemap) (0.11.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from anywidget->geemap) (4.12.2)
# Requirement already satisfied: traitlets>=4.3.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: bqscales<0.4,>=0.3.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from bqplot->geemap) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages\pytz-2025.1-py3.11.egg (from pandas->geemap) (2025.1)
# Requirement already satisfied: click in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geocoder->geemap) (8.1.7)
# Requirement already satisfied: future in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages\future-0.18.3-py3.11.egg (from geocoder->geemap) (0.18.3)
# Requirement already satisfied: ratelim in c:\users\dell\appdata\roaming\python\python311\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (24.2)
# Requirement already satisfied: pillow>=8 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (3.2.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from plotly->geemap) (2.21.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->geemap) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->geemap) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->geemap) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->geemap) (2025.1.31)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (2.30.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->geemap) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->geemap) (43.0.1)
# Requirement already satisfied: comm>=0.1.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.32.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: colorama in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api>=1.6.12->geemap) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api>=1.6.12->geemap) (2.9.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api>=1.6.12->geemap) (1.8.0)
# Requirement already satisfied: decorator in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: cffi>=1.12 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api>=1.6.12->geemap) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (1.75.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (7.35.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (1.28.0)
# Requirement already satisfied: jedi>=0.16 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.18.0)
# Requirement already satisfied: stack_data in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.5.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.6.12->geemap) (0.6.3)
# Requirement already satisfied: pycparser in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api>=1.6.12->geemap) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: wcwidth in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: executing in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: asttokens in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.5)
# Requirement already satisfied: pure-eval in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geetools in c:\users\dell\appdata\roaming\python\python311\site-packages (1.18.1)
# Requirement already satisfied: anyascii in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (0.3.3)
# Requirement already satisfied: deprecated in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (1.3.1)
# Requirement already satisfied: earthengine-api>=1.6.12 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (1.7.28)
# Requirement already satisfied: ee-extra>=2025.7.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (2025.7.2)
# Requirement already satisfied: geopandas in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (1.1.3)
# Requirement already satisfied: matplotlib in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geetools) (3.9.4)
# Requirement already satisfied: pandas in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geetools) (2.2.3)
# Requirement already satisfied: requests in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geetools) (2.32.3)
# Requirement already satisfied: xee>=0.0.11 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (0.1.1)
# Requirement already satisfied: yamlable in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (1.1.1)
# Requirement already satisfied: google-cloud-storage in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geetools) (3.10.1)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geetools) (2.196.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geetools) (2.53.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geetools) (0.4.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api>=1.6.12->geetools) (0.31.2)
# Requirement already satisfied: xarray[parallel] in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from xee>=0.0.11->geetools) (2024.11.0)
# Requirement already satisfied: pyproj in c:\users\dell\appdata\roaming\python\python311\site-packages (from xee>=0.0.11->geetools) (3.7.2)
# Requirement already satisfied: affine in c:\users\dell\appdata\roaming\python\python311\site-packages (from xee>=0.0.11->geetools) (2.4.0)
# Requirement already satisfied: shapely in c:\users\dell\appdata\roaming\python\python311\site-packages (from xee>=0.0.11->geetools) (2.1.2)
# Requirement already satisfied: wrapt<3,>=1.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from deprecated->geetools) (1.17.0)
# Requirement already satisfied: numpy>=1.24 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geopandas->geetools) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geopandas->geetools) (0.12.1)
# Requirement already satisfied: packaging in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geopandas->geetools) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from pandas->geetools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages\pytz-2025.1-py3.11.egg (from pandas->geetools) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geetools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geetools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geetools) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geetools) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geetools) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geetools) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->geetools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->geetools) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->geetools) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->geetools) (2025.1.31)
# Requirement already satisfied: PyYaml in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from yamlable->geetools) (6.0.2)
# Requirement already satisfied: six in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from yamlable->geetools) (1.16.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geetools) (2.30.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geetools) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->geetools) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->geetools) (43.0.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api>=1.6.12->geetools) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api>=1.6.12->geetools) (2.9.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api>=1.6.12->geetools) (1.8.0)
# Requirement already satisfied: dask[complete] in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from xarray[parallel]->xee>=0.0.11->geetools) (2024.12.1)
# Requirement already satisfied: cffi>=1.12 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api>=1.6.12->geetools) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geetools) (1.75.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geetools) (7.35.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geetools) (1.28.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.6.12->geetools) (0.6.3)
# Requirement already satisfied: click>=8.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (2024.12.0)
# Requirement already satisfied: partd>=1.4.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (8.5.0)
# Requirement already satisfied: pyarrow>=14.0.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (24.0.0)
# Requirement already satisfied: lz4>=4.3.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (4.3.2)
# Requirement already satisfied: pycparser in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api>=1.6.12->geetools) (2.21)
# Requirement already satisfied: colorama in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from click>=8.1->dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from importlib-metadata>=4.13.0->dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (3.21.0)
# Requirement already satisfied: locket in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from partd>=1.4.0->dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (1.0.0)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (1.1.21)
# Requirement already satisfied: bokeh>=3.1.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (3.9.0)
# Requirement already satisfied: jinja2>=2.10.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (3.1.5)
# Requirement already satisfied: distributed==2024.12.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (2024.12.1)
# Requirement already satisfied: msgpack>=1.0.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (1.0.3)
# Requirement already satisfied: psutil>=5.8.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (5.9.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (1.7.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (6.4.2)
# Requirement already satisfied: zict>=3.0.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (3.0.0)
# Requirement already satisfied: narwhals>=1.13 in c:\users\dell\appdata\roaming\python\python311\site-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (2.21.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jinja2>=2.10.3->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (3.0.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: earthengine-api in c:\users\dell\appdata\roaming\python\python311\site-packages (1.7.28)
# Requirement already satisfied: geemap in c:\users\dell\appdata\roaming\python\python311\site-packages (0.37.2)
# Requirement already satisfied: geetools in c:\users\dell\appdata\roaming\python\python311\site-packages (1.18.1)
# Requirement already satisfied: google-cloud-storage in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api) (3.10.1)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api) (2.196.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api) (2.53.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api) (0.4.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from earthengine-api) (0.31.2)
# Requirement already satisfied: requests in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: anywidget in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (0.9.13)
# Requirement already satisfied: bqplot in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.13.1)
# Requirement already satisfied: eerepr>=0.1.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.1.2)
# Requirement already satisfied: folium>=0.17.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.20.0)
# Requirement already satisfied: geocoder in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (2.0.4)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.20.0)
# Requirement already satisfied: matplotlib in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (3.9.4)
# Requirement already satisfied: numpy in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (2.2.3)
# Requirement already satisfied: plotly in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (6.7.0)
# Requirement already satisfied: pyperclip in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (1.11.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (7.4.1)
# Requirement already satisfied: scooby in c:\users\dell\appdata\roaming\python\python311\site-packages (from geemap) (0.11.2)
# Requirement already satisfied: anyascii in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (0.3.3)
# Requirement already satisfied: deprecated in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (1.3.1)
# Requirement already satisfied: ee-extra>=2025.7.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (2025.7.2)
# Requirement already satisfied: geopandas in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (1.1.3)
# Requirement already satisfied: xee>=0.0.11 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (0.1.1)
# Requirement already satisfied: yamlable in c:\users\dell\appdata\roaming\python\python311\site-packages (from geetools) (1.1.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from folium>=0.17.0->geemap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from folium>=0.17.0->geemap) (3.1.5)
# Requirement already satisfied: xyzservices in c:\users\dell\appdata\roaming\python\python311\site-packages (from folium>=0.17.0->geemap) (2026.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.30.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (43.0.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.0)
# Requirement already satisfied: ipywidgets in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.5)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipyleaflet>=0.19.2->geemap) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.3)
# Requirement already satisfied: xarray[parallel] in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from xee>=0.0.11->geetools) (2024.11.0)
# Requirement already satisfied: pyproj in c:\users\dell\appdata\roaming\python\python311\site-packages (from xee>=0.0.11->geetools) (3.7.2)
# Requirement already satisfied: affine in c:\users\dell\appdata\roaming\python\python311\site-packages (from xee>=0.0.11->geetools) (2.4.0)
# Requirement already satisfied: shapely in c:\users\dell\appdata\roaming\python\python311\site-packages (from xee>=0.0.11->geetools) (2.1.2)
# Requirement already satisfied: psygnal>=0.8.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from anywidget->geemap) (0.11.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from anywidget->geemap) (4.12.2)
# Requirement already satisfied: traitlets>=4.3.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: bqscales<0.4,>=0.3.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from bqplot->geemap) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages\pytz-2025.1-py3.11.egg (from pandas->geemap) (2025.1)
# Requirement already satisfied: wrapt<3,>=1.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from deprecated->geetools) (1.17.0)
# Requirement already satisfied: click in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geocoder->geemap) (8.1.7)
# Requirement already satisfied: future in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages\future-0.18.3-py3.11.egg (from geocoder->geemap) (0.18.3)
# Requirement already satisfied: ratelim in c:\users\dell\appdata\roaming\python\python311\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from geopandas->geetools) (0.12.1)
# Requirement already satisfied: packaging in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geopandas->geetools) (24.2)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api) (2.9.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api) (1.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->earthengine-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->earthengine-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->earthengine-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->earthengine-api) (2025.1.31)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (11.1.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from plotly->geemap) (2.21.2)
# Requirement already satisfied: PyYaml in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from yamlable->geetools) (6.0.2)
# Requirement already satisfied: cffi>=1.12 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.75.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (7.35.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.28.0)
# Requirement already satisfied: comm>=0.1.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.32.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.3)
# Requirement already satisfied: colorama in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: decorator in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: dask[complete] in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from xarray[parallel]->xee>=0.0.11->geetools) (2024.12.1)
# Requirement already satisfied: pycparser in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api) (2.21)
# Requirement already satisfied: jedi>=0.16 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.18.0)
# Requirement already satisfied: stack_data in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.5.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (2024.12.0)
# Requirement already satisfied: partd>=1.4.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (8.5.0)
# Requirement already satisfied: pyarrow>=14.0.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (24.0.0)
# Requirement already satisfied: lz4>=4.3.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (4.3.2)
# Requirement already satisfied: zipp>=3.20 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from importlib-metadata>=4.13.0->dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: locket in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from partd>=1.4.0->dask[complete]; extra == "parallel"->xarray[parallel]->xee>=0.0.11->geetools) (1.0.0)
# Requirement already satisfied: wcwidth in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (1.1.21)
# Requirement already satisfied: bokeh>=3.1.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (3.9.0)
# Requirement already satisfied: distributed==2024.12.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (2024.12.1)
# Requirement already satisfied: msgpack>=1.0.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (1.0.3)
# Requirement already satisfied: psutil>=5.8.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (5.9.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (1.7.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (6.4.2)
# Requirement already satisfied: zict>=3.0.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from distributed==2024.12.1->dask[complete]->xarray[parallel]->xee>=0.0.11->geetools) (3.0.0)
# Requirement already satisfied: executing in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: asttokens in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.5)
# Requirement already satisfied: pure-eval in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)

# %%
#Import Libraries
import ee 
import geemap
import geetools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Import Libraries
# ----> 2 import ee
#       3 import geemap
#       4 import geetools
#
# ModuleNotFoundError: No module named 'ee'

# %%
#authenticate and initialize ee

ee.Authenticate()
#ee.Authenticate(auth_mode='notebook', cloud_api=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %%
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Define individual features
B1 = ee.Feature(ee.Geometry.Point([-79.21025, 35.14636]), {'name': 'B1', 'type': 'site'})
B2 = ee.Feature(ee.Geometry.Point([-79.19908, 35.14625]), {'name': 'B2', 'type': 'site'})
CM = ee.Feature(ee.Geometry.Point([-76.97426, 34.76602]), {'name': 'CM', 'type': 'site'})
CH = ee.Feature(ee.Geometry.Point([-76.87395833, 34.767175]), {'name': 'CH', 'type': 'site'})
ME = ee.Feature(ee.Geometry.Point([-77.47046, 34.64371]), {'name': 'ME', 'type': 'site'})
IA = ee.Feature(ee.Geometry.Point([-77.30881, 34.59154]), {'name': 'IA', 'type': 'site'})
GSP_BI = ee.Feature(ee.Geometry.Point([-78.30196, 34.08546]), {'name': 'GSP_BI', 'type': 'site'})
GSP_LI = ee.Feature(ee.Geometry.Point([-78.29995, 34.081985]), {'name': 'GSP_LI', 'type': 'site'})
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Create a FeatureCollection
VFT_sites = ee.FeatureCollection([B1, B2, CM,CH,ME,IA,GSP_BI,GSP_LI])
#bands = ['SR_B1','SR_B3','SR_B4','SR_B5', 'SR_B7','QA_PIXEL'] 
bands= ['SR_B1','SR_B2','SR_B3','SR_B4','SR_B5', 'SR_B6','SR_B7','QA_PIXEL']
#bands = image.bandNames()         # add desirable bands, and QA_pixel (cloud info). Depends on the index to calculate. Modify this when switching satellites
roi_GSP = ee.Geometry.Rectangle([-78.33, 34.05, -78.24, 34.13])  # [minLon, minLat, maxLon, maxLat]
roi_Lej = ee.Geometry.Rectangle([-77.55, 34.52, -77.23, 34.73])  # [minLon, minLat, maxLon, maxLat]
roi_Cro = ee.Geometry.Rectangle([-77.02, 34.72, -76.83, 34.82])  # [minLon, minLat, maxLon, maxLat]
roi_BR = ee.Geometry.Rectangle([-79.225, 35.13, -79.19, 35.16])  # [minLon, minLat, maxLon, maxLat]

## added roi

roi_Cro_new
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
collection = (ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')  # LANDSAT/LT05/C02/T1_L2    LANDSAT/LC08/C02/T1_L2
    .filterDate('2024-5-29', '2024-6-20')   
    .filterBounds(roi_Cro)  # Change ROI as needed 
    .select(bands)  # Select required bands, make su;re QA_pixel is in there
)

# Check number of images remaining
print("Number of images after filtering:", collection.size().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of images after filtering: 2

# %%
import time
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def export_image(image):
    img_id = image.get('system:index').getInfo()
    
    # Convert to float and clip to roi
    image = image.float().clip(roi_Cro)  # modify this when switching areas

    task = ee.batch.Export.image.toDrive(
        image=image,
        description=f'Landsat_{img_id}',
        folder='Landsat8_Cro_test_1',  # Google Drive Folder   # modify this when switching areas
        fileNamePrefix=f'Landsat_{img_id}',
        scale=30,  # 30m resolution
        region=roi_Cro.getInfo()['coordinates'],     # modify this when switching areas
        maxPixels=1e13
    )
    task.start()
    return task, img_id  # Return task and image ID for monitoring

# Convert collection to list and check if it contains images
num_images = collection.size().getInfo()
if num_images == 0:
    raise ValueError("🚨 No images found! ")

print(f"✅ Found {num_images} images. Starting export...")

# Export each image
image_list = collection.toList(num_images)
tasks = []

for i in range(num_images):
    img = ee.Image(image_list.get(i))
    task, img_id = export_image(img)
    tasks.append((task, img_id))  # Store task for monitoring

print("\n🚀 Batch export started. Monitoring progress...\n")

# Function to check task status
def check_task_status(tasks):
    while any(task.status()['state'] in ['READY', 'RUNNING'] for task, _ in tasks):
        print("\n🔄 Current Export Status:")
        for task, img_id in tasks:
            status = task.status()
            print(f"  - {img_id}: {status['state']}")
        time.sleep(100)  # Wait 5 minutes before checking again

    print("\n✅ All tasks completed!")

# Monitor progress
check_task_status(tasks)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Found 2 images. Starting export...
#
# 🚀 Batch export started. Monitoring progress...
#
#
# 🔄 Current Export Status:
#   - LC08_014036_20240530: READY
#   - LC08_014036_20240615: READY
#
# ✅ All tasks completed!

# %%
import os, glob
print(os.getcwd())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# F:\VFT\VFT_github\zyao78VFTcode

# %%
from googleapiclient.errors import HttpError

def merge_folders_by_name(folder_name: str, delete_duplicates=True, dry_run=False):
    # Drive v2 query: use title (not name)
    q = ("title = '{0}' and "
         "mimeType = 'application/vnd.google-apps.folder' and trashed = false").format(folder_name)

    folders = drive.ListFile({
        'q': q,
        'supportsAllDrives': True,
        'includeItemsFromAllDrives': True,
        'maxResults': 1000
    }).GetList()

    if len(folders) < 2:
        print(f"Found {len(folders)} folder(s) named '{folder_name}'. Nothing to merge.")
        return

    target = folders[0]
    target_id = target['id']
    print(f"Found {len(folders)} folder(s) named '{folder_name}'.")
    print(f"Target: {target['title']} ({target_id})")

    svc = drive.auth.service

    for dup in folders[1:]:
        dup_id = dup['id']
        print(f"Merging: {dup['title']} ({dup_id}) -> {folder_name}")

        children = drive.ListFile({
            'q': f"'{dup_id}' in parents and trashed = false",
            'supportsAllDrives': True,
            'includeItemsFromAllDrives': True,
            'maxResults': 1000
        }).GetList()

        for it in children:
            file_id = it['id']
            title   = it['title']

            if dry_run:
                print(f"  would move: {title} -> target ({target_id})")
                continue

            # remove other parents and add target
            old_parents = ",".join(p['id'] for p in it.get('parents', []) if p['id'] != target_id)
            svc.files().update(
                fileId=file_id,
                addParents=target_id,
                removeParents=old_parents,
                supportsAllDrives=True
            ).execute()
            print(f"  moved: {title}")

        if not dry_run and delete_duplicates:
            svc.files().delete(fileId=dup_id, supportsAllDrives=True).execute()
            print(f"  deleted folder: {dup['title']} ({dup_id})")

    print("Done.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

# Sign in with your Google account (opens a browser tab)
gauth = GoogleAuth()
gauth.LocalWebserverAuth()
drive = GoogleDrive(gauth)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=548363215141-24o3chdgv280l66mi2s58ebv2bga5kkm.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=online&response_type=code
#
# Authentication successful.

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

# assume you've already authenticated: gauth = GoogleAuth(); gauth.LocalWebserverAuth()
# drive = GoogleDrive(gauth)

def _list(q: str):
    return drive.ListFile({
        'q': q,
        'supportsAllDrives': True,
        'includeItemsFromAllDrives': True
    }).GetList()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Dry run
merge_folders_by_name("Landsat8_Cro_test", dry_run=True)
# Out:
# Found 29 folder(s) named 'Landsat8_BR'.
# Target: Landsat8_BR (19fgXJUseqMq3qA9oln_BVT93vf8TSe8N)
# Merging: Landsat8_BR (1hAihZsoRwcrRMEdpGKeHvLoxpMuzkuNm)
#   would move: Landsat_LC08_016035_20241206.tif -> Landsat8_BR
# Merging: Landsat8_BR (1GmKJpeHLkuaWygO1QgtbufpshC23OcJD)
#   would move: Landsat_LC08_016035_20250107.tif -> Landsat8_BR
# Merging: Landsat8_BR (1oKENsNLUpuQ5RfrRCsgmyig78b2e5ua9)
#   would move: Landsat_LC08_016035_20250123.tif -> Landsat8_BR
# Merging: Landsat8_BR (1LqBFTJizRscJrVX956PjksCUcAWFcWfS)
#   would move: Landsat_LC08_016035_20250224.tif -> Landsat8_BR
# Merging: Landsat8_BR (1h8KcGT5QLtkV4hpitniycEIvdzmQ_kQL)
#   would move: Landsat_LC08_016035_20250312.tif -> Landsat8_BR
# Merging: Landsat8_BR (1gjomPxEne401T_ybHieY6Xl-eOyvW5IA)
#   would move: Landsat_LC08_016035_20250328.tif -> Landsat8_BR
# Merging: Landsat8_BR (1G7ZaNu0yD4YRe4P37kScR8cIAsj00REn)
#   would move: Landsat_LC08_016035_20250413.tif -> Landsat8_BR
# Merging: Landsat8_BR (1k3BqCi_igKxjOoY7OyYC7a0h79hxQJB8)
#   would move: Landsat_LC08_016035_20250429.tif -> Landsat8_BR
# Merging: Landsat8_BR (1OjywdLgE6BEP-gvaNJSAX5coKXFtPpud)
#   would move: Landsat_LC08_016035_20250515.tif -> Landsat8_BR
# Merging: Landsat8_BR (14Pu7V8eGg0Lccx2oygohcimIP4tGag67)
#   would move: Landsat_LC08_016035_20250531.tif -> Landsat8_BR
# Merging: Landsat8_BR (1pdUIN5AjvdYjQFguESjxTc-EGyGPQYfa)
#   would move: Landsat_LC08_016035_20250616.tif -> Landsat8_BR
# Merging: Landsat8_BR (1Zei3kiOOf5CSV24J0RWuDTDoDa9UX5Ly)
#   would move: Landsat_LC08_016035_20250718.tif -> Landsat8_BR
# Merging: Landsat8_BR (1nxRQLNuki04BMyC16IJPx7aVgy5d1j4V)
#   would move: Landsat_LC08_016035_20250803.tif -> Landsat8_BR
# Merging: Landsat8_BR (1QX4ogu7FF-nEkqlJd1kaIXwmNtiRkOll)
#   would move: Landsat_LC08_016036_20241206.tif -> Landsat8_BR
# Merging: Landsat8_BR (1lsWUgez-rDPJWwn3bDThltgfB5cfA59Y)
#   would move: Landsat_LC08_016036_20241222.tif -> Landsat8_BR
# Merging: Landsat8_BR (1i8pFwRFcg8kx8TCAhKctiUFgILmk69Nn)
#   would move: Landsat_LC08_016036_20250107.tif -> Landsat8_BR
# Merging: Landsat8_BR (1xg1aXn4h-_dBLQgyX1Nztua-nKLBN5C6)
#   would move: Landsat_LC08_016036_20250123.tif -> Landsat8_BR
# Merging: Landsat8_BR (19UQukUc9Dwx3ug7jyiPwp9aaY3hiAdyW)
#   would move: Landsat_LC08_016036_20250224.tif -> Landsat8_BR
# Merging: Landsat8_BR (13RG512yRtVw6EKxuw430UZVCmozmD_ec)
#   would move: Landsat_LC08_016036_20250312.tif -> Landsat8_BR
# Merging: Landsat8_BR (1yMTs9BFQS6PEmG9_XssfbrdjbBphUApK)
#   would move: Landsat_LC08_016036_20250328.tif -> Landsat8_BR
# Merging: Landsat8_BR (1a9fgRX9L-v58JzgD2zOybszINlNxFxJD)
#   would move: Landsat_LC08_016036_20250413.tif -> Landsat8_BR
# Merging: Landsat8_BR (1BFeQGVS4NQHIiCTRupUeQwe2aRi5qMoM)
#   would move: Landsat_LC08_016036_20250429.tif -> Landsat8_BR
# Merging: Landsat8_BR (1JaK0cps--yP7qjSU00QvB637p8vuBekr)
#   would move: Landsat_LC08_016036_20250515.tif -> Landsat8_BR
# Merging: Landsat8_BR (1kre72ckntpymWywMLBJyYR0LreZ0w3MT)
#   would move: Landsat_LC08_016036_20250531.tif -> Landsat8_BR
# Merging: Landsat8_BR (1RCdwAJlSp701Uf66hPY18-JelWKGkL7s)
#   would move: Landsat_LC08_016036_20250616.tif -> Landsat8_BR
# Merging: Landsat8_BR (12ohJUdWIOI16tAEE8FfX5IrzAhgMV-WP)
#   would move: Landsat_LC08_016036_20250702.tif -> Landsat8_BR
# Merging: Landsat8_BR (1SphKYFmi6_-naKum-G-fwAp6HJtjsNVZ)
#   would move: Landsat_LC08_016036_20250718.tif -> Landsat8_BR
# Merging: Landsat8_BR (1zC2rKbf6wfBJDDcOJvcT9kilx31f45d_)
#   would move: Landsat_LC08_016036_20250803.tif -> Landsat8_BR
# Done.

# %%
merge_folders_by_name("Landsat8_Cro_test", dry_run=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found 5 folder(s) named 'Landsat8_Cro_test'.
# Target: Landsat8_Cro_test (1JHUsqIhykPScylZ5zUKODw1ELKyFBzkT)
# Merging: Landsat8_Cro_test (1xuC6V_5AnJxvoa-XVDhcTSH4kMfTSaBb) -> Landsat8_Cro_test
#   moved: Landsat_LC08_014036_20170730.tif
#   deleted folder: Landsat8_Cro_test (1xuC6V_5AnJxvoa-XVDhcTSH4kMfTSaBb)
# Merging: Landsat8_Cro_test (1uuH_rUXi2AxdAySIDy0CjW2BSbduw_wf) -> Landsat8_Cro_test
#   moved: Landsat_LC08_014036_20170714.tif
#   deleted folder: Landsat8_Cro_test (1uuH_rUXi2AxdAySIDy0CjW2BSbduw_wf)
# Merging: Landsat8_Cro_test (1qlzgddd6bQxHjpljPwJbcSHOOyO-7vCR) -> Landsat8_Cro_test
#   moved: Landsat_LC08_014036_20170612.tif
#   deleted folder: Landsat8_Cro_test (1qlzgddd6bQxHjpljPwJbcSHOOyO-7vCR)
# Merging: Landsat8_Cro_test (1CpZ4-SXMNZQSM0f5CBmdWnzCImOQARB_) -> Landsat8_Cro_test
#   moved: Landsat_LC08_014036_20170628.tif
#   deleted folder: Landsat8_Cro_test (1CpZ4-SXMNZQSM0f5CBmdWnzCImOQARB_)
# Done.
