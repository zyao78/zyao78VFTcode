# %%
# !pip install geemap
# !pip install geetools
# Out:
# Requirement already satisfied: geemap in c:\users\dell\anaconda3\envs\vft\lib\site-packages (0.34.3)
# Requirement already satisfied: bqplot in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (0.12.44)
# Requirement already satisfied: colour in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=1.0.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (1.1.5)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (0.1.1)
# Requirement already satisfied: folium>=0.13.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (0.18.0)
# Requirement already satisfied: geocoder in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.17.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (3.7.5)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (1.24.4)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (2.0.3)
# Requirement already satisfied: plotly in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (6.0.1)
# Requirement already satisfied: pyperclip in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.1.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (7.2.0)
# Requirement already satisfied: scooby in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geemap) (75.3.0)
# Requirement already satisfied: google-cloud-storage in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api>=1.0.0->geemap) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.164.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from folium>=0.13.0->geemap) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from folium>=0.13.0->geemap) (3.1.4)
# Requirement already satisfied: xyzservices in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from folium>=0.13.0->geemap) (2025.1.0)
# Requirement already satisfied: ipywidgets in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipyleaflet>=0.17.0->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from pandas->geemap) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: click in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geocoder->geemap) (8.1.8)
# Requirement already satisfied: future in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from matplotlib->geemap) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from matplotlib->geemap) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from matplotlib->geemap) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from matplotlib->geemap) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from matplotlib->geemap) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from matplotlib->geemap) (3.1.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from matplotlib->geemap) (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from plotly->geemap) (1.31.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (4.9)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->geemap) (3.20.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.12.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from jinja2>=2.9->folium>=0.13.0->geemap) (2.1.3)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2024.8.30)
# Requirement already satisfied: decorator in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.69.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (5.29.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.26.1)
# Requirement already satisfied: backcall in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.11.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: executing in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: geetools in c:\users\dell\anaconda3\envs\vft\lib\site-packages (1.1.0)
# Requirement already satisfied: deprecated in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geetools) (1.2.18)
# Requirement already satisfied: earthengine-api in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geetools) (1.1.5)
# Requirement already satisfied: ee-extra in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geetools) (0.0.15)
# Requirement already satisfied: geopandas in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geetools) (0.13.2)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geetools) (2.0.3)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geetools) (2.32.3)
# Requirement already satisfied: xee in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geetools) (0.0.20)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from deprecated->geetools) (1.17.2)
# Requirement already satisfied: google-cloud-storage in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api->geetools) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api->geetools) (2.164.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api->geetools) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api->geetools) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from earthengine-api->geetools) (0.22.0)
# Requirement already satisfied: fiona>=1.8.19 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geopandas->geetools) (1.10.1)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geopandas->geetools) (24.1)
# Requirement already satisfied: pyproj>=3.0.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geopandas->geetools) (3.5.0)
# Requirement already satisfied: shapely>=1.7.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from geopandas->geetools) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from pandas->geetools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from pandas->geetools) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from pandas->geetools) (2025.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from pandas->geetools) (1.24.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from requests->geetools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from requests->geetools) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from requests->geetools) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from requests->geetools) (2024.8.30)
# Requirement already satisfied: xarray[parallel] in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from xee->geetools) (2023.1.0)
# Requirement already satisfied: affine in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from xee->geetools) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from fiona>=1.8.19->geopandas->geetools) (24.2.0)
# Requirement already satisfied: click~=8.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from fiona>=1.8.19->geopandas->geetools) (8.1.8)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from fiona>=1.8.19->geopandas->geetools) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from fiona>=1.8.19->geopandas->geetools) (0.7.2)
# Requirement already satisfied: importlib-metadata in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from fiona>=1.8.19->geopandas->geetools) (7.0.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api->geetools) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api->geetools) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-auth>=1.4.1->earthengine-api->geetools) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-auth>=1.4.1->earthengine-api->geetools) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-auth>=1.4.1->earthengine-api->geetools) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api->geetools) (3.1.4)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from python-dateutil>=2.8.2->pandas->geetools) (1.16.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-cloud-storage->earthengine-api->geetools) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-cloud-storage->earthengine-api->geetools) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-cloud-storage->earthengine-api->geetools) (1.5.0)
# Requirement already satisfied: dask[complete] in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from xarray[parallel]->xee->geetools) (2023.5.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas->geetools) (0.4.6)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->geetools) (1.69.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->geetools) (5.29.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->geetools) (1.26.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api->geetools) (0.6.1)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee->geetools) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee->geetools) (2025.3.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee->geetools) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee->geetools) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee->geetools) (1.0.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee->geetools) (17.0.0)
# Requirement already satisfied: lz4>=4.3.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee->geetools) (4.3.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from importlib-metadata->fiona>=1.8.19->geopandas->geetools) (3.20.2)
# Requirement already satisfied: locket in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from partd>=1.2.0->dask[complete]; extra == "parallel"->xarray[parallel]->xee->geetools) (1.0.0)
# Requirement already satisfied: distributed==2023.5.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]->xarray[parallel]->xee->geetools) (2023.5.0)
# Requirement already satisfied: bokeh>=2.4.2 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]->xarray[parallel]->xee->geetools) (3.1.1)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from dask[complete]->xarray[parallel]->xee->geetools) (3.1.4)
# Requirement already satisfied: msgpack>=1.0.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from distributed==2023.5.0->dask[complete]->xarray[parallel]->xee->geetools) (1.1.0)
# Requirement already satisfied: psutil>=5.7.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from distributed==2023.5.0->dask[complete]->xarray[parallel]->xee->geetools) (5.9.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from distributed==2023.5.0->dask[complete]->xarray[parallel]->xee->geetools) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from distributed==2023.5.0->dask[complete]->xarray[parallel]->xee->geetools) (3.0.0)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from distributed==2023.5.0->dask[complete]->xarray[parallel]->xee->geetools) (6.4.1)
# Requirement already satisfied: zict>=2.2.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from distributed==2023.5.0->dask[complete]->xarray[parallel]->xee->geetools) (3.0.0)
# Requirement already satisfied: contourpy>=1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from bokeh>=2.4.2->dask[complete]->xarray[parallel]->xee->geetools) (1.1.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from bokeh>=2.4.2->dask[complete]->xarray[parallel]->xee->geetools) (10.4.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from bokeh>=2.4.2->dask[complete]->xarray[parallel]->xee->geetools) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\vft\lib\site-packages (from jinja2>=2.10.3->dask[complete]->xarray[parallel]->xee->geetools) (2.1.3)

# %%
#Import Libraries
import ee 
import geemap
import geetools

# %%
#authenticate and initialize ee

ee.Authenticate()
#ee.Authenticate(auth_mode='notebook', cloud_api=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %%
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Define individual features
B1 = ee.Feature(ee.Geometry.Point([-79.21025, 35.14636]), {'name': 'B1', 'type': 'site'})
B2 = ee.Feature(ee.Geometry.Point([-79.19908, 35.14625]), {'name': 'B2', 'type': 'site'})
CM = ee.Feature(ee.Geometry.Point([-76.97426, 34.76602]), {'name': 'CM', 'type': 'site'})
CH = ee.Feature(ee.Geometry.Point([-76.87395833, 34.767175]), {'name': 'CH', 'type': 'site'})
ME = ee.Feature(ee.Geometry.Point([-77.47046, 34.64371]), {'name': 'ME', 'type': 'site'})
IA = ee.Feature(ee.Geometry.Point([-77.30881, 34.59154]), {'name': 'IA', 'type': 'site'})
GSP_BI = ee.Feature(ee.Geometry.Point([-78.30196, 34.08546]), {'name': 'GSP_BI', 'type': 'site'})
GSP_LI = ee.Feature(ee.Geometry.Point([-78.29995, 34.081985]), {'name': 'GSP_LI', 'type': 'site'})
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Create a FeatureCollection
VFT_sites = ee.FeatureCollection([B1, B2, CM,CH,ME,IA,GSP_BI,GSP_LI])
#bands = ['SR_B1','SR_B3','SR_B4','SR_B5', 'SR_B7','QA_PIXEL'] 
bands= ['SR_B1','SR_B3','SR_B4','SR_B5', 'SR_B7','QA_PIXEL']
#bands = image.bandNames()         # add desirable bands, and QA_pixel (cloud info). Depends on the index to calculate. Modify this when switching satellites
roi_GSP = ee.Geometry.Rectangle([-78.33, 34.05, -78.24, 34.13])  # [minLon, minLat, maxLon, maxLat]
roi_Lej = ee.Geometry.Rectangle([-77.55, 34.52, -77.23, 34.73])  # [minLon, minLat, maxLon, maxLat]
roi_Cro = ee.Geometry.Rectangle([-77.02, 34.72, -76.83, 34.82])  # [minLon, minLat, maxLon, maxLat]
roi_BR = ee.Geometry.Rectangle([-79.225, 35.13, -79.19, 35.16])  # [minLon, minLat, maxLon, maxLat]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
collection = (ee.ImageCollection('LANDSAT/LT04/C02/T1_L2')  # LANDSAT/LT05/C02/T1_L2    LANDSAT/LC08/C02/T1_L2
    .filterDate('1982-8-22', '1984-11-18')   
    .filterBounds(roi_BR)  # Change ROI as needed 
    .select(bands)  # Select required bands, make su;re QA_pixel is in there
)

# Check number of images remaining
print("Number of images after filtering:", collection.size().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of images after filtering: 2

# %%
import time
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def export_image(image):
    img_id = image.get('system:index').getInfo()
    
    # Convert to float and clip to roi
    image = image.float().clip(roi_BR)  # modify this when switching areas

    task = ee.batch.Export.image.toDrive(
        image=image,
        description=f'Landsat_{img_id}',
        folder='Landsat4_BR',  # Google Drive Folder   # modify this when switching areas
        fileNamePrefix=f'Landsat_{img_id}',
        scale=30,  # 30m resolution
        region=roi_BR.getInfo()['coordinates'],     # modify this when switching areas
        maxPixels=1e13
    )
    task.start()
    return task, img_id  # Return task and image ID for monitoring

# Convert collection to list and check if it contains images
num_images = collection.size().getInfo()
if num_images == 0:
    raise ValueError("🚨 No images found! ")

print(f"✅ Found {num_images} images. Starting export...")

# Export each image
image_list = collection.toList(num_images)
tasks = []

for i in range(num_images):
    img = ee.Image(image_list.get(i))
    task, img_id = export_image(img)
    tasks.append((task, img_id))  # Store task for monitoring

print("\n🚀 Batch export started. Monitoring progress...\n")

# Function to check task status
def check_task_status(tasks):
    while any(task.status()['state'] in ['READY', 'RUNNING'] for task, _ in tasks):
        print("\n🔄 Current Export Status:")
        for task, img_id in tasks:
            status = task.status()
            print(f"  - {img_id}: {status['state']}")
        time.sleep(100)  # Wait 5 minutes before checking again

    print("\n✅ All tasks completed!")

# Monitor progress
check_task_status(tasks)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Found 2 images. Starting export...
#
# 🚀 Batch export started. Monitoring progress...
#
#
# 🔄 Current Export Status:
#   - LT04_016036_19821125: READY
#   - LT04_016036_19830128: READY
#
# ✅ All tasks completed!

# %%
Map = geemap.Map(center=[35.14636, -79.21025], zoom=15)
Map.addLayer(feature_collection, {'color': 'Green'}, 'VFT sites')
Map
